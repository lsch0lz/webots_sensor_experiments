# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../results/touch_sensor.csv")
df.head()
# Out:
#    left_force  right_force  sum_force
# 0   27.743935    24.637601  52.381536
# 1   34.494681    31.077554  65.572235
# 2   46.503011    49.792356  96.295368
# 3   29.851756    41.949738  71.801494
# 4   18.777079    54.513929  73.291008

# %%
plt.figure(figsize=(10, 5), dpi=144)
ax=plt.subplot(111)
#ax.set_xlim(235, 310)
ax.plot(list(range(0, len(df.left_force))), df.left_force, label = "Left Foot")
ax.plot(list(range(0, len(df.right_force))), df.right_force, label = "Right Foot")
ax.plot(list(range(0, len(df.sum_force))), df.sum_force, label = "SUM Force")

ax.set_ylabel("Nm")
ax.set_xlabel("t")

plt.legend()
plt.show()
